# %%
# lesion overlap, fa, various modification options; some graph properties
# volumetric and streamlinetric

# %% [markdown]
# # Make a Virtual Lesion

# %%
import os,sys
sys.path.append('/home/jgriffiths/Code/libraries_of_mine/github/ConWhAt')

from conwhat import VolTractAtlas
from conwhat.viz.volume import plot_vol_scatter

# %%
jhu_vta = VolTractAtlas('JHU')
# Out:
# loading file mapping
# loading vol bbox

# %%
jhu_test_file = '../conwhat/scratch/lesion_test_file_from_jhu.nii.gz'

# %% [markdown]
# 'We make use of bounding boxes to speed things up.

# %%
# %matplotlib nbagg

# %%
ax = plot_vol_scatter(jhu_vta.get_vol_from_vfm(1),c='b',bg_img='nilearn_destrieux')
plot_vol_scatter(jhu_vta.get_vol_from_vfm(1),ax=ax,c='r')
plot_vol_scatter(jhu_vta.get_vol_from_vfm(2),ax=ax,c='cyan')

plot_vol_scatter(jhu_vta.get_vol_from_vfm(2),ax=ax,c='cyan')

plot_vol_scatter(jhu_test_file,ax=ax, c='k')
# Out:
# getting atlas entry 1: volume 1 from image file /usr/share/fsl/data/atlases/JHU/JHU-ICBM-tracts-prob-2mm.nii.gz
# <img src="data:image/png;base64,...">
# getting atlas entry 1: volume 1 from image file /usr/share/fsl/data/atlases/JHU/JHU-ICBM-tracts-prob-2mm.nii.gz
# getting atlas entry 2: volume 2 from image file /usr/share/fsl/data/atlases/JHU/JHU-ICBM-tracts-prob-2mm.nii.gz
# getting atlas entry 2: volume 2 from image file /usr/share/fsl/data/atlases/JHU/JHU-ICBM-tracts-prob-2mm.nii.gz

# %%
from conwhat import VolConnAtlas

# %%
cw_vca = VolConnAtlas('CW_l2k8sc33')
# Out:
# loading file mapping
# loading vol bbox
# loading connectivity

# %%
from conwhat.viz.volume import plot_vol_and_rois_nilearn

# %%
labels_file = '/home/jgriffiths/Code/libraries_of_mine/github/ConWhAt/conwhat/data/CW_l2k8sc33/ROI_scale33.nii.gz'

# %%
an_img = cw_vca.get_vol_from_vfm(0)
# Out:
# getting atlas entry 0: volume 0 from image file /home/jgriffiths/Code/libraries_of_mine/github/ConWhAt/conwhat/utils/../data/CW_l2k8sc33/vismap_grp_cat_rois1_norm.nii.gz

# %%
another_img = cw_vca.get_vol_from_rois(1,5)

# %%
# %matplotlib inline

# %%
# need to 

roi1 = 2
roi2 = 23
plot_vol_and_rois_nilearn(cw_vca.get_vol_from_rois(roi1,roi2),
                          labels=labels_file,roi1=roi1+1,roi2=roi2+1)

# %%
# need to 

roi1 = 5
roi2 = 30
plot_vol_and_rois_nilearn(cw_vca.get_vol_from_rois(roi1,roi2),
                          labels=labels_file,roi1=roi1+1,roi2=roi2+1)

# %%
# need to 

roi1 = 10
roi2 = 35
plot_vol_and_rois_nilearn(cw_vca.get_vol_from_rois(roi1,roi2),
                          labels=labels_file,roi1=roi1+1,roi2=roi2+1)

# %%
# need to get the roi colours wa bit better there
# and make thresholding work better

# and be able to add on a lesion

# but that looks basically ok...
